# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport #pip install pandas-profiling
from sklearn import (
    ensemble,
    preprocessing,
    tree,
)
from sklearn.metrics import (
    auc,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
)
from yellowbrick.classifier import (
    ConfusionMatrix,
    ROCAUC,
)
from yellowbrick.model_selection import (
    LearningCurve,
)
import os
import xlrd
# Out:
# <ipython-input-11-b2217371da5d>:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %% [markdown]
# ### Belowe two ways of import xls from Google Drive

# %%
# import from google drive by Mount Drive
path = '/content/drive/MyDrive/Github/ML-Python-pocket-lexicon/titanic3.xls'
df = pd.read_excel(path)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2f0b046da92b> in <cell line: 3>()
#       1 # import from google drive by Mount Drive
#       2 path = '/content/drive/MyDrive/Github/ML-Python-pocket-lexicon/titanic3.xls'
# ----> 3 df = pd.read_excel(path)
#       4 df.head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import from google drive direct
from google.colab import drive
drive.mount("/content/drive")
path = '/content/drive/MyDrive/Github/ML-Python-pocket-lexicon/titanic3.xls'
df = pd.read_excel(path)
df.head(5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %% [markdown]
# ### 1. Clearing data

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-05-13 07:38:01.287224&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
res = df.describe().iloc[:, :2]
output = res.rename(
    {"count": "liczba", "mean":"srednia", "std" : "odch. stand."}, axis = 'index'
)
output
# Out:
#                    pclass     survived
# liczba        1309.000000  1309.000000
# srednia          2.294882     0.381971
# odch. stand.     0.837836     0.486055
# min              1.000000     0.000000
# 25%              2.000000     0.000000
# 50%              3.000000     0.000000
# 75%              3.000000     1.000000
# max              3.000000     1.000000

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.isnull().mean()
# Out:
# pclass       0.000000
# survived     0.000000
# name         0.000000
# sex          0.000000
# age          0.200917
# sibsp        0.000000
# parch        0.000000
# ticket       0.000000
# fare         0.000764
# cabin        0.774637
# embarked     0.001528
# boat         0.628724
# body         0.907563
# home.dest    0.430863
# dtype: float64

# %%
df.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
mask = df.isnull().any(axis = 0)
mask.head(10)
# Out:
# pclass      False
# survived    False
# name        False
# sex         False
# age          True
# sibsp       False
# parch       False
# ticket      False
# fare         True
# cabin        True
# dtype: bool

# %%
df.sex.value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df.embarked.value_counts(dropna = False)
# Out:
# S      914
# C      270
# Q      123
# NaN      2
# Name: embarked, dtype: int64

# %% [markdown]
# ## Zdefiniowanie cech

# %%
name = df.name
name.head(3)
# Out:
# 0     Allen, Miss. Elisabeth Walton
# 1    Allison, Master. Hudson Trevor
# 2      Allison, Miss. Helen Loraine
# Name: name, dtype: object

# %%
df = df.drop(columns = ['name', 'ticket', 'home.dest', 'boat', 'body', 'cabin'])

# %%
df.head(4)
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare embarked
# 0       1         1  female  29.0000      0      0  211.3375        S
# 1       1         1    male   0.9167      1      2  151.5500        S
# 2       1         0  female   2.0000      1      2  151.5500        S
# 3       1         0    male  30.0000      1      2  151.5500        S
